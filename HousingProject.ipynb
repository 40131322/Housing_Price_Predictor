# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.colors as mcolors

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import f1_score, classification_report

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %%
pd.options.display.max_rows = 100

df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# 5     6          50       RL         85.0    14115   Pave   NaN      IR1
# 6     7          20       RL         75.0    10084   Pave   NaN      Reg
# 7     8          60       RL          NaN    10382   Pave   NaN      IR1
# 8     9          50       RM         51.0     6120   Pave   NaN      Reg
# 9    10         190       RL         50.0     7420   Pave   NaN      Reg
# 10   11          20       RL         70.0    11200   Pave   NaN      Reg
# 11   12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# Clearing out all columns containing too many null values

# %%
df.isna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df.isna(axis=1)
#
# TypeError: DataFrame.isna() got an unexpected keyword argument 'axis'

# %%
#Defining and dealing with the null values
NANcolumns = df.columns[df.isnull().any()].tolist()

# %%
NANcolumns
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
df = df.dropna(axis=1, thresh=999)
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# 1stFlrSF           0
# 2ndFlrSF           0
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# Transforming the data related to Garage

# %%
garage = df[['GarageType'
,'GarageYrBlt'
,'GarageFinish'
,'GarageCars'
,'GarageArea'
,'GarageQual'
,'GarageCond']]

# %%
print(garage['GarageType'].unique())

print(garage['GarageYrBlt'].unique())

print(garage['GarageCars'].unique())

print(garage['GarageArea'].unique())

print(garage['GarageQual'].unique())

print(garage['GarageCond'].unique())
# Out:
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# [2003. 1976. 2001. 1998. 2000. 1993. 2004. 1973. 1931. 1939. 1965. 2005.
#  1962. 2006. 1960. 1991. 1970. 1967. 1958. 1930. 2002. 1968. 2007. 2008.
#  1957. 1920. 1966. 1959. 1995. 1954. 1953.   nan 1983. 1977. 1997. 1985.
#  1963. 1981. 1964. 1999. 1935. 1990. 1945. 1987. 1989. 1915. 1956. 1948.
#  1974. 2009. 1950. 1961. 1921. 1900. 1979. 1951. 1969. 1936. 1975. 1971.
#  1923. 1984. 1926. 1955. 1986. 1988. 1916. 1932. 1972. 1918. 1980. 1924.
#  1996. 1940. 1949. 1994. 1910. 1978. 1982. 1992. 1925. 1941. 2010. 1927.
#  1947. 1937. 1942. 1938. 1952. 1928. 1922. 1934. 1906. 1914. 1946. 1908.
#  1929. 1933.]
# [2 3 1 0 4]
# [ 548  460  608  642  836  480  636  484  468  205  384  736  352  840
#   576  516  294  853  280  534  572  270  890  772  319  240  250  271
#   447  556  691  672  498  246    0  440  308  504  300  670  826  386
#   388  528  894  565  641  288  645  852  558  220  667  360  427  490
# ...

# %%
df[['GarageType'

,'GarageFinish'

,'GarageQual'
,'GarageCond']].fillna('None',inplace = True)
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageCars       0
# GarageArea       0
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
garage['GarageType'].fillna('None',inplace = True)

# %%
def fill_null_values_string (df, columns, value):
    for col in columns:
        df[col].fillna(value, inplace=True)
    return df
def fill_null_values_num (df, columns):
    for col in columns:
        value = df[col].mean()
        df[col].fillna(value, inplace=True)
    return df

# %%
garagecolumns = ['GarageType','GarageFinish','GarageQual','GarageCond']

# %%
df[NANcolumns]
# Out:
#       LotFrontage  MasVnrArea BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0            65.0       196.0       Gd       TA           No          GLQ
# 1            80.0         0.0       Gd       TA           Gd          ALQ
# 2            68.0       162.0       Gd       TA           Mn          GLQ
# 3            60.0         0.0       TA       Gd           No          ALQ
# 4            84.0       350.0       Gd       TA           Av          GLQ
# ...           ...         ...      ...      ...          ...          ...
# 1455         62.0         0.0       Gd       TA           No          Unf
# 1456         85.0       119.0       Gd       TA           No          ALQ
# 1457         66.0         0.0       TA       Gd           No          GLQ
# 1458         68.0         0.0       TA       TA           Mn          GLQ
# 1459         75.0         0.0       TA       TA           No          BLQ
#
#      BsmtFinType2 Electrical GarageType  GarageYrBlt GarageFinish GarageQual  \
# ...
